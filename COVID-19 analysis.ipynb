# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from matplotlib.animation import FuncAnimation
from matplotlib import style

# %%
total_deaths=pd.read_csv('total_deaths.csv',parse_dates=['date'])
total_deaths.head()
# Out:
#         date  World  Afghanistan  Albania  Algeria  Andorra  \
# 0 2020-01-21      6          NaN      NaN      NaN      NaN
# 1 2020-01-22      6          NaN      NaN      NaN      NaN
# 2 2020-01-23     17          NaN      NaN      NaN      NaN
# 3 2020-01-24     25          NaN      NaN      NaN      NaN
# 4 2020-01-25     41          NaN      NaN      NaN      NaN
#
#    Antigua and Barbuda  Argentina  Armenia  Australia  ...  \
# 0                  NaN        NaN      NaN        NaN  ...
# 1                  NaN        NaN      NaN        NaN  ...
# 2                  NaN        NaN      NaN        NaN  ...
# 3                  NaN        NaN      NaN        NaN  ...
# 4                  NaN        NaN      NaN        NaN  ...
#
#    Trinidad and Tobago  Tunisia  Turkey  Ukraine  United Arab Emirates  \
# 0                  NaN      NaN     NaN      NaN                   NaN
# 1                  NaN      NaN     NaN      NaN                   NaN
# ...

# %%
total_deaths.set_index('date',inplace=True)

# %%
total_cases=pd.read_csv('total_cases.csv',parse_dates=['date'])
total_cases.head()
# Out:
#         date  World  Afghanistan  Albania  Algeria  Andorra  \
# 0 2020-01-21    282          NaN      NaN      NaN      NaN
# 1 2020-01-22    314          NaN      NaN      NaN      NaN
# 2 2020-01-23    581          NaN      NaN      NaN      NaN
# 3 2020-01-24    846          NaN      NaN      NaN      NaN
# 4 2020-01-25   1320          NaN      NaN      NaN      NaN
#
#    Antigua and Barbuda  Argentina  Armenia  Australia  ...  \
# 0                  NaN        NaN      NaN        NaN  ...
# 1                  NaN        NaN      NaN        NaN  ...
# 2                  NaN        NaN      NaN        NaN  ...
# 3                  NaN        NaN      NaN        NaN  ...
# 4                  NaN        NaN      NaN        3.0  ...
#
#    Trinidad and Tobago  Tunisia  Turkey  Ukraine  United Arab Emirates  \
# 0                  NaN      NaN     NaN      NaN                   NaN
# 1                  NaN      NaN     NaN      NaN                   NaN
# ...

# %%
total_cases.set_index('date',inplace=True)
total_cases.head()
# Out:
#             World  Afghanistan  Albania  Algeria  Andorra  \
# date
# 2020-01-21    282          NaN      NaN      NaN      NaN
# 2020-01-22    314          NaN      NaN      NaN      NaN
# 2020-01-23    581          NaN      NaN      NaN      NaN
# 2020-01-24    846          NaN      NaN      NaN      NaN
# 2020-01-25   1320          NaN      NaN      NaN      NaN
#
#             Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# date                                                                     ...
# 2020-01-21                  NaN        NaN      NaN        NaN      NaN  ...
# 2020-01-22                  NaN        NaN      NaN        NaN      NaN  ...
# 2020-01-23                  NaN        NaN      NaN        NaN      NaN  ...
# 2020-01-24                  NaN        NaN      NaN        NaN      NaN  ...
# 2020-01-25                  NaN        NaN      NaN        3.0      NaN  ...
#
#             Trinidad and Tobago  Tunisia  Turkey  Ukraine  \
# date
# ...

# %%
total_cases.shape
# Out:
# (55, 146)

# %%
total_cases['World'].max()
# Out:
# 153523

# %%
total_cases.tail()
# Out:
#              World  Afghanistan  Albania  Algeria  Andorra  \
# date
# 2020-03-11  118319          4.0     10.0     20.0      1.0
# 2020-03-12  125260          7.0     10.0     25.0      1.0
# 2020-03-13  132758          7.0     23.0     25.0      1.0
# 2020-03-14  142539          7.0     33.0     26.0      2.0
# 2020-03-15  153523         10.0     38.0     37.0      2.0
#
#             Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# date                                                                     ...
# 2020-03-11                  NaN       17.0      1.0      112.0    182.0  ...
# 2020-03-12                  NaN       19.0      1.0      122.0    302.0  ...
# 2020-03-13                  NaN       31.0      1.0      140.0    361.0  ...
# 2020-03-14                  1.0       34.0      8.0      197.0    504.0  ...
# 2020-03-15                  1.0       45.0      8.0      249.0    800.0  ...
#
#             Trinidad and Tobago  Tunisia  Turkey  Ukraine  \
# ...

# %%
print(total_cases.index[-1])
# Out:
# 2020-03-15 00:00:00

# %%
plt.figure(figsize=(13,12))
plt.title('COVID-19 Reports worldwide')
plt.ylabel('Number of COVID-19 cases')
plt.xlabel('Date')
plt.plot(total_cases.index,total_cases['World'],'r',label='Reported Corona infection cases')
plt.plot(total_deaths.index,total_deaths['World'],'b',label='Reported Corona Deaths')
plt.grid(True,color='g')
plt.legend()
plt.style.use('ggplot')
plt.savefig('covid-19.jpeg')
plt.show()
